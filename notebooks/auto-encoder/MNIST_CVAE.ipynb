# %% [markdown]
# # ConditionalVariationalAutoEncoderの実装

# %%
import torch #基本モジュール
from torch.autograd import Variable #自動微分用
import torch.nn as nn #ネットワーク構築用
import torch.optim as optim #最適化関数
import torch.nn.functional as F #ネットワーク用の様々な関数
import torch.utils.data #データセット読み込み関連 p
import torchvision #画像関連
from torchvision import datasets, models, transforms #画像用データセット諸々

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import cloudpickle

from utils import try_gpu

# %% [markdown]
# ## モデル構築

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, output_size, c_size):
        # side_size: 画像の1辺サイズ
        # output_size: 出力サイズ
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(input_size+c_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4_mu = nn.Linear(32, output_size)
        self.fc4_var = nn.Linear(32, output_size)

    def forward(self, x, c):
        x = torch.cat([x, c], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        # 分散は非負値の前提
        return self.fc4_mu(x), F.softplus(self.fc4_var(x))

Encoder(28*28, 2, 10)
# Out:
# Encoder(
#   (fc1): Linear(in_features=794, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4_mu): Linear(in_features=32, out_features=2, bias=True)
#   (fc4_var): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
class Decoder(nn.Module):
    def __init__(self, input_size, output_size, c_size):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(input_size+c_size, 32)
        self.fc2 = nn.Linear(32, 64)
        self.fc3 = nn.Linear(64, 128)
        self.fc4 = nn.Linear(128, output_size)

    def forward(self, x, c):
        x = torch.cat([x, c], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        return x

Decoder(2, 28*28, 10)
# Out:
# Decoder(
#   (fc1): Linear(in_features=12, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
# )

# %%
def one_hot(labels, class_size):
    targets = torch.zeros(labels.size(0), class_size)
    for i, label in enumerate(labels):
        targets[i, label] = 1
    return try_gpu(Variable(targets))

# %%
class CVAE(nn.Module):
    def __init__(self, inout_size, latent_size, c_size):
        # inout_size:inとoutのサイズ
        # latent_size:潜在空間の次元数
        super(CVAE, self).__init__()
        self.inout_size = inout_size
        self.latent_size = latent_size
        self.c_size = c_size
        
        self.encoder = Encoder(inout_size, latent_size, c_size)
        self.decoder = Decoder(latent_size, inout_size, c_size)
        
    def forward(self, x, c):
        x = x.view(-1, 784)
        mu, var = self.encoder(x, c)
        z = self.reparameterize(mu, var)
        x_hat = self.decoder(z, c)
        return x_hat, mu, var
    
    def reparameterize(self, mu, var):
        epsilon = torch.randn(mu.shape)
        epsilon = try_gpu(epsilon)
        return mu + epsilon * torch.sqrt(var)
    
    def loss(self, x_hat, x, mu, var):
        # reconstruction loss：入力画像をどのくらい正確に復元できたか？
        # 数式では対数尤度の最大化だが, 交差エントロピーlossの最小化と等価
        recon = F.binary_cross_entropy(x_hat, x.view(-1, 784), reduction='sum')
        # 正則化項：q(z|x)が p(z)~N(0, I) に近くなるようにする
        # 正規分布の KL Divergence
        # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
        kld = -0.5 * torch.sum(1 + torch.log(var) - mu**2 - var)
        return recon + kld
    
    def forward_calculate_loss(self, data):
        # 1batch における loss 計算
        # data_loader から渡される mini_batch から loss を計算
        imgs, labels = data
        x = try_gpu(Variable(imgs))
        labels = one_hot(labels, self.c_size)
        x_hat, mu, var = self(x, labels)
        return self.loss(x_hat, x, mu, var)

# %%
from utils import init_model
model = init_model(CVAE, inout_size=28*28, latent_size=2, c_size=10)
model
# Out:
# CVAE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=794, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=32, bias=True)
#     (fc4_mu): Linear(in_features=32, out_features=2, bias=True)
#     (fc4_var): Linear(in_features=32, out_features=2, bias=True)
#   )
#   (decoder): Decoder(
#     (fc1): Linear(in_features=12, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=128, bias=True)
#     (fc4): Linear(in_features=128, out_features=784, bias=True)
#   )
# )

# %% [markdown]
# ## 学習

# %%
from utils import make_dataset_loader, run_train_test

# %%
# train settings
model_name = 'cvae'
num_epochs = 100
batch_size = 256
learning_rate = 1e-3
model = init_model(CVAE, inout_size=28*28, latent_size=16, c_size=10)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)

# data download
task_name = 'mnist'
load_func = torchvision.datasets.MNIST
train_dataset_loader, test_dataset_loader = make_dataset_loader(batch_size, load_func)
# Out:
# loaded <class 'torchvision.datasets.mnist.MNIST'> train:60000, test:10000

# %%
trained_dict = run_train_test(model, model_name, task_name, optimizer, num_epochs, train_dataset_loader, test_dataset_loader)
# Out:
# make dir ./runs/mnist/cvae/20191107T031525, ./models/mnist/cvae/20191107T031525
# epoch [1/100], step:235, loss:231.5447, test_loss:191.8341, {'elapsed': '5秒', 'remain': '9分'}
# model save to ./models/mnist/cvae/20191107T031525/epoch001.pt
# epoch [2/100], step:470, loss:179.1508, test_loss:166.9988, {'elapsed': '10秒', 'remain': '8分56秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch002.pt
# epoch [3/100], step:705, loss:160.4917, test_loss:152.8885, {'elapsed': '16秒', 'remain': '8分49秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch003.pt
# epoch [4/100], step:940, loss:147.9612, test_loss:142.7533, {'elapsed': '21秒', 'remain': '8分44秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch004.pt
# epoch [5/100], step:1175, loss:139.9372, test_loss:136.1557, {'elapsed': '27秒', 'remain': '8分38秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch005.pt
# epoch [6/100], step:1410, loss:134.7320, test_loss:132.8727, {'elapsed': '32秒', 'remain': '8分34秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch006.pt
# epoch [7/100], step:1645, loss:130.9967, test_loss:128.7165, {'elapsed': '38秒', 'remain': '8分28秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch007.pt
# epoch [8/100], step:1880, loss:127.9211, test_loss:125.8236, {'elapsed': '43秒', 'remain': '8分22秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch008.pt
# epoch [9/100], step:2115, loss:125.4706, test_loss:123.8064, {'elapsed': '49秒', 'remain': '8分17秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch009.pt
# epoch [10/100], step:2350, loss:123.6863, test_loss:122.2533, {'elapsed': '54秒', 'remain': '8分11秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch010.pt
# epoch [11/100], step:2585, loss:122.3468, test_loss:120.9869, {'elapsed': '1分', 'remain': '8分5秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch011.pt
# epoch [12/100], step:2820, loss:121.2699, test_loss:120.0929, {'elapsed': '1分5秒', 'remain': '8分'}
# model save to ./models/mnist/cvae/20191107T031525/epoch012.pt
# epoch [13/100], step:3055, loss:120.3062, test_loss:118.9511, {'elapsed': '1分11秒', 'remain': '7分55秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch013.pt
# epoch [14/100], step:3290, loss:119.4374, test_loss:118.7433, {'elapsed': '1分16秒', 'remain': '7分49秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch014.pt
# epoch [15/100], step:3525, loss:118.7023, test_loss:118.0671, {'elapsed': '1分21秒', 'remain': '7分44秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch015.pt
# epoch [16/100], step:3760, loss:118.0475, test_loss:117.1144, {'elapsed': '1分27秒', 'remain': '7分38秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch016.pt
# epoch [17/100], step:3995, loss:117.4724, test_loss:116.6346, {'elapsed': '1分32秒', 'remain': '7分33秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch017.pt
# epoch [18/100], step:4230, loss:116.9271, test_loss:116.3161, {'elapsed': '1分38秒', 'remain': '7分28秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch018.pt
# epoch [19/100], step:4465, loss:116.4789, test_loss:115.7090, {'elapsed': '1分43秒', 'remain': '7分22秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch019.pt
# epoch [20/100], step:4700, loss:115.9820, test_loss:115.2303, {'elapsed': '1分49秒', 'remain': '7分17秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch020.pt
# epoch [21/100], step:4935, loss:115.6847, test_loss:115.4909, {'elapsed': '1分54秒', 'remain': '7分12秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch021.pt
# epoch [22/100], step:5170, loss:115.3165, test_loss:114.5383, {'elapsed': '2分', 'remain': '7分6秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch022.pt
# epoch [23/100], step:5405, loss:114.9341, test_loss:114.5009, {'elapsed': '2分6秒', 'remain': '7分2秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch023.pt
# epoch [24/100], step:5640, loss:114.6143, test_loss:114.1064, {'elapsed': '2分11秒', 'remain': '6分57秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch024.pt
# epoch [25/100], step:5875, loss:114.3268, test_loss:113.9570, {'elapsed': '2分17秒', 'remain': '6分52秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch025.pt
# epoch [26/100], step:6110, loss:114.0343, test_loss:113.6883, {'elapsed': '2分23秒', 'remain': '6分47秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch026.pt
# epoch [27/100], step:6345, loss:113.7682, test_loss:113.5306, {'elapsed': '2分28秒', 'remain': '6分42秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch027.pt
# epoch [28/100], step:6580, loss:113.5437, test_loss:113.0083, {'elapsed': '2分34秒', 'remain': '6分37秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch028.pt
# epoch [29/100], step:6815, loss:113.3459, test_loss:112.9034, {'elapsed': '2分39秒', 'remain': '6分31秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch029.pt
# epoch [30/100], step:7050, loss:113.1316, test_loss:112.6915, {'elapsed': '2分45秒', 'remain': '6分25秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch030.pt
# epoch [31/100], step:7285, loss:112.8800, test_loss:112.6355, {'elapsed': '2分51秒', 'remain': '6分20秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch031.pt
# epoch [32/100], step:7520, loss:112.7384, test_loss:112.8241, {'elapsed': '2分56秒', 'remain': '6分15秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch032.pt
# epoch [33/100], step:7755, loss:112.5403, test_loss:112.0186, {'elapsed': '3分2秒', 'remain': '6分9秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch033.pt
# epoch [34/100], step:7990, loss:112.3452, test_loss:112.1613, {'elapsed': '3分7秒', 'remain': '6分3秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch034.pt
# epoch [35/100], step:8225, loss:112.1724, test_loss:111.6332, {'elapsed': '3分12秒', 'remain': '5分58秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch035.pt
# epoch [36/100], step:8460, loss:112.0436, test_loss:111.9440, {'elapsed': '3分18秒', 'remain': '5分52秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch036.pt
# epoch [37/100], step:8695, loss:111.8500, test_loss:111.5125, {'elapsed': '3分23秒', 'remain': '5分47秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch037.pt
# epoch [38/100], step:8930, loss:111.7282, test_loss:111.4211, {'elapsed': '3分29秒', 'remain': '5分41秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch038.pt
# epoch [39/100], step:9165, loss:111.6386, test_loss:111.6588, {'elapsed': '3分34秒', 'remain': '5分35秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch039.pt
# epoch [40/100], step:9400, loss:111.4440, test_loss:111.6530, {'elapsed': '3分40秒', 'remain': '5分30秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch040.pt
# epoch [41/100], step:9635, loss:111.3525, test_loss:111.0613, {'elapsed': '3分45秒', 'remain': '5分24秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch041.pt
# epoch [42/100], step:9870, loss:111.1769, test_loss:110.9826, {'elapsed': '3分51秒', 'remain': '5分19秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch042.pt
# epoch [43/100], step:10105, loss:111.0797, test_loss:111.1416, {'elapsed': '3分56秒', 'remain': '5分13秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch043.pt
# epoch [44/100], step:10340, loss:110.9287, test_loss:110.9447, {'elapsed': '4分2秒', 'remain': '5分8秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch044.pt
# epoch [45/100], step:10575, loss:110.8534, test_loss:110.7738, {'elapsed': '4分7秒', 'remain': '5分2秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch045.pt
# epoch [46/100], step:10810, loss:110.7367, test_loss:110.6575, {'elapsed': '4分13秒', 'remain': '4分57秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch046.pt
# epoch [47/100], step:11045, loss:110.6469, test_loss:110.7550, {'elapsed': '4分18秒', 'remain': '4分51秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch047.pt
# epoch [48/100], step:11280, loss:110.4906, test_loss:110.5692, {'elapsed': '4分24秒', 'remain': '4分46秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch048.pt
# epoch [49/100], step:11515, loss:110.3729, test_loss:110.2898, {'elapsed': '4分29秒', 'remain': '4分40秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch049.pt
# epoch [50/100], step:11750, loss:110.3723, test_loss:110.7407, {'elapsed': '4分35秒', 'remain': '4分35秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch050.pt
# epoch [51/100], step:11985, loss:110.2271, test_loss:110.4692, {'elapsed': '4分40秒', 'remain': '4分29秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch051.pt
# epoch [52/100], step:12220, loss:110.1812, test_loss:110.4075, {'elapsed': '4分45秒', 'remain': '4分23秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch052.pt
# epoch [53/100], step:12455, loss:110.0435, test_loss:110.0655, {'elapsed': '4分51秒', 'remain': '4分18秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch053.pt
# epoch [54/100], step:12690, loss:109.9262, test_loss:110.0681, {'elapsed': '4分57秒', 'remain': '4分13秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch054.pt
# epoch [55/100], step:12925, loss:109.8428, test_loss:110.2321, {'elapsed': '5分2秒', 'remain': '4分7秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch055.pt
# epoch [56/100], step:13160, loss:109.7448, test_loss:109.7382, {'elapsed': '5分8秒', 'remain': '4分2秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch056.pt
# epoch [57/100], step:13395, loss:109.6832, test_loss:109.9576, {'elapsed': '5分13秒', 'remain': '3分56秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch057.pt
# epoch [58/100], step:13630, loss:109.5885, test_loss:109.5780, {'elapsed': '5分19秒', 'remain': '3分51秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch058.pt
# epoch [59/100], step:13865, loss:109.4497, test_loss:109.4729, {'elapsed': '5分24秒', 'remain': '3分45秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch059.pt
# epoch [60/100], step:14100, loss:109.3657, test_loss:109.7668, {'elapsed': '5分30秒', 'remain': '3分40秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch060.pt
# epoch [61/100], step:14335, loss:109.3317, test_loss:109.5428, {'elapsed': '5分35秒', 'remain': '3分34秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch061.pt
# epoch [62/100], step:14570, loss:109.2124, test_loss:109.4764, {'elapsed': '5分41秒', 'remain': '3分29秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch062.pt
# epoch [63/100], step:14805, loss:109.1317, test_loss:109.7792, {'elapsed': '5分47秒', 'remain': '3分23秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch063.pt
# epoch [64/100], step:15040, loss:109.1134, test_loss:109.1663, {'elapsed': '5分52秒', 'remain': '3分18秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch064.pt
# epoch [65/100], step:15275, loss:109.0275, test_loss:109.3561, {'elapsed': '5分57秒', 'remain': '3分12秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch065.pt
# epoch [66/100], step:15510, loss:108.9619, test_loss:109.3130, {'elapsed': '6分3秒', 'remain': '3分7秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch066.pt
# epoch [67/100], step:15745, loss:108.9296, test_loss:109.5639, {'elapsed': '6分9秒', 'remain': '3分1秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch067.pt
# epoch [68/100], step:15980, loss:108.8169, test_loss:109.1352, {'elapsed': '6分14秒', 'remain': '2分56秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch068.pt
# epoch [69/100], step:16215, loss:108.7306, test_loss:109.1520, {'elapsed': '6分20秒', 'remain': '2分50秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch069.pt
# epoch [70/100], step:16450, loss:108.6668, test_loss:109.0579, {'elapsed': '6分25秒', 'remain': '2分45秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch070.pt
# epoch [71/100], step:16685, loss:108.5873, test_loss:109.0416, {'elapsed': '6分31秒', 'remain': '2分39秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch071.pt
# epoch [72/100], step:16920, loss:108.5516, test_loss:108.7479, {'elapsed': '6分36秒', 'remain': '2分34秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch072.pt
# epoch [73/100], step:17155, loss:108.4833, test_loss:108.6786, {'elapsed': '6分42秒', 'remain': '2分28秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch073.pt
# epoch [74/100], step:17390, loss:108.3782, test_loss:108.7297, {'elapsed': '6分48秒', 'remain': '2分23秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch074.pt
# epoch [75/100], step:17625, loss:108.3351, test_loss:108.9626, {'elapsed': '6分53秒', 'remain': '2分17秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch075.pt
# epoch [76/100], step:17860, loss:108.2950, test_loss:108.9351, {'elapsed': '6分59秒', 'remain': '2分12秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch076.pt
# epoch [77/100], step:18095, loss:108.2099, test_loss:108.7548, {'elapsed': '7分4秒', 'remain': '2分6秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch077.pt
# epoch [78/100], step:18330, loss:108.1807, test_loss:108.7135, {'elapsed': '7分10秒', 'remain': '2分1秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch078.pt
# epoch [79/100], step:18565, loss:108.0856, test_loss:108.5746, {'elapsed': '7分15秒', 'remain': '1分55秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch079.pt
# epoch [80/100], step:18800, loss:108.0429, test_loss:108.4776, {'elapsed': '7分21秒', 'remain': '1分50秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch080.pt
# epoch [81/100], step:19035, loss:108.0198, test_loss:108.6165, {'elapsed': '7分26秒', 'remain': '1分44秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch081.pt
# epoch [82/100], step:19270, loss:107.9584, test_loss:108.1803, {'elapsed': '7分32秒', 'remain': '1分39秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch082.pt
# epoch [83/100], step:19505, loss:107.8619, test_loss:108.4903, {'elapsed': '7分37秒', 'remain': '1分33秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch083.pt
# epoch [84/100], step:19740, loss:107.8036, test_loss:108.5996, {'elapsed': '7分43秒', 'remain': '1分28秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch084.pt
# epoch [85/100], step:19975, loss:107.8502, test_loss:108.4566, {'elapsed': '7分48秒', 'remain': '1分22秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch085.pt
# epoch [86/100], step:20210, loss:107.7455, test_loss:108.7063, {'elapsed': '7分54秒', 'remain': '1分17秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch086.pt
# epoch [87/100], step:20445, loss:107.7092, test_loss:108.1998, {'elapsed': '7分59秒', 'remain': '1分11秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch087.pt
# epoch [88/100], step:20680, loss:107.6287, test_loss:108.3014, {'elapsed': '8分5秒', 'remain': '1分6秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch088.pt
# epoch [89/100], step:20915, loss:107.6098, test_loss:108.2086, {'elapsed': '8分10秒', 'remain': '1分'}
# model save to ./models/mnist/cvae/20191107T031525/epoch089.pt
# epoch [90/100], step:21150, loss:107.5830, test_loss:108.0029, {'elapsed': '8分16秒', 'remain': '55秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch090.pt
# epoch [91/100], step:21385, loss:107.5385, test_loss:108.0354, {'elapsed': '8分21秒', 'remain': '49秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch091.pt
# epoch [92/100], step:21620, loss:107.4854, test_loss:108.4331, {'elapsed': '8分27秒', 'remain': '44秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch092.pt
# epoch [93/100], step:21855, loss:107.4096, test_loss:108.1343, {'elapsed': '8分32秒', 'remain': '38秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch093.pt
# epoch [94/100], step:22090, loss:107.3890, test_loss:108.3419, {'elapsed': '8分38秒', 'remain': '33秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch094.pt
# epoch [95/100], step:22325, loss:107.3626, test_loss:107.8367, {'elapsed': '8分43秒', 'remain': '27秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch095.pt
# epoch [96/100], step:22560, loss:107.3298, test_loss:108.1574, {'elapsed': '8分49秒', 'remain': '22秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch096.pt
# epoch [97/100], step:22795, loss:107.3254, test_loss:108.0011, {'elapsed': '8分54秒', 'remain': '16秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch097.pt
# epoch [98/100], step:23030, loss:107.2219, test_loss:108.6209, {'elapsed': '9分', 'remain': '11秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch098.pt
# epoch [99/100], step:23265, loss:107.1963, test_loss:108.1711, {'elapsed': '9分5秒', 'remain': '5秒'}
# model save to ./models/mnist/cvae/20191107T031525/epoch099.pt
# epoch [100/100], step:23500, loss:107.1506, test_loss:108.5965, {'elapsed': '9分11秒', 'remain': ''}
# model save to ./models/mnist/cvae/20191107T031525/epoch100.pt

# %%
from utils import extract_scalar_from_event, plot_from_dict

scalar_dict = extract_scalar_from_event(trained_dict['log_dir'])
plt.figure(figsize=(10, 5))
plot_from_dict(scalar_dict, 'train/loss')

# %%
plt.figure(figsize=(10, 5))
plot_from_dict(scalar_dict, 'test/loss')

# %% [markdown]
# ## デコード出力描画
#
# epochごとの学習具合を確認

# %%
from utils import load_model, plot_gray_img

# %%
def output_shaped(model, imgs, labels):
    # modelからのAEの出力を描画用にreshapeして出力
    size = int(np.sqrt(model.inout_size))
    output, mu, var  = model(try_gpu(imgs.view(-1, size*size)), labels)
    return output.view(-1, 1, size, size).cpu().data

# %%
from glob import glob
model_path_list = glob(f'{trained_dict["model_dir"]}/*.pt')
model_path_list = sorted(model_path_list)

# %%
model = load_model(model_path_list[-1])

# %%
model
# Out:
# CVAE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=794, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=32, bias=True)
#     (fc4_mu): Linear(in_features=32, out_features=16, bias=True)
#     (fc4_var): Linear(in_features=32, out_features=16, bias=True)
#   )
#   (decoder): Decoder(
#     (fc1): Linear(in_features=26, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=128, bias=True)
#     (fc4): Linear(in_features=128, out_features=784, bias=True)
#   )
# )

# %%
def make_dummy_onehot_label(label):
    _input_onehot_label = try_gpu(torch.zeros(1, 10))
    _input_onehot_label[0][label] = 1
    return _input_onehot_label

# %%
_imgs, _labels = iter(test_dataset_loader).next()
_onehot_labels = one_hot(_labels, 10)
_input_img = _imgs[0].view(28, 28)
_onehot_label = _onehot_labels[0].view(1, 10)
plt.title('origin')
_label, plot_gray_img(_input_img)
# Out:
# (9, None)

# %%
# %%time
_onehot_label = make_dummy_onehot_label(8)
_output_img = output_shaped(model, _input_img, _onehot_label).view(28, 28)
plt.title('model output')
plot_gray_img(_output_img)
# Out:
# CPU times: user 22.5 ms, sys: 274 µs, total: 22.7 ms
# Wall time: 20.3 ms

# %%
import os
from utils import plot_img_grid

# %%
_input_imgs, _labels = iter(test_dataset_loader).next()
_input_imgs, _labels = _input_imgs[:9*9], _labels[:9*9]
_onehot_labels = one_hot(_labels, 10)
decode_dir = f'./decode/{task_name}/{model_name}'
os.makedirs(decode_dir, exist_ok=True)
plot_img_grid(_input_imgs, 9, f'{decode_dir}/origin.png', 'origin')

# %%
# 最後のモデルの出力
latest_model_output = output_shaped(model, _input_imgs, _onehot_labels)
plot_img_grid(latest_model_output, 9, title='model output')

# %% [markdown]
# ### 数字ラベルのみを変更して実験

# %%
plt.title('origin')
plot_gray_img(_input_img)
plt.show()

for _label in range(10):
    _onehot_label = make_dummy_onehot_label(_label)
    _output_img = output_shaped(model, _input_img, _onehot_label).view(28, 28)
    plt.title(f'output {_label}')
    plot_gray_img(_output_img)
    plt.show()

# %% [markdown]
# 一気に出力

# %%
import re
import os
from tqdm import tqdm
for model_path in tqdm(model_path_list):
    model = load_model(model_path)
    output = output_shaped(model, _input_imgs, _onehot_labels)
    epoch = re.sub("\\D", "", os.path.basename(model_path))
    plot_img_grid(output, title=f'epoch: {epoch}', save_path=f'./decode/{task_name}/{model_name}/epoch{epoch}.png', nrow=9)

# %% [markdown]
# Gifにする

# %%
from PIL import Image, ImageDraw
git_output_path = f'./decode/{task_name}/{model_name}/model_outputs.gif'
images = [Image.open(img_path) for img_path in sorted(glob(f'./decode/{task_name}/{model_name}/*.png'))]
images[0].save(git_output_path, save_all=True, append_images=images[1:], optimize=False, duration=100, loop=0)
git_output_path
# Out:
# './decode/mnist/cvae/model_outputs.gif'

# %% [markdown]
# ## 潜在空間の分布
#
# せっかく2次元まで圧縮したので分布を確認する

# %%
model = load_model(model_path_list[-1])

# %%
from tqdm import tqdm
label_xy_list = [[] for _ in range(10)]
for img, label in tqdm(test_dataset_loader.dataset):
    onehot_label = try_gpu(torch.zeros(1, 10))
    mu, var = model.encoder(try_gpu(img.view(-1, 28*28)), onehot_label)
    mu = mu.data.cpu().numpy()[0]
    var = var.data.cpu().numpy()[0]
    label_xy_list[label].append([mu, var])
# Out:
# 100%|██████████| 10000/10000 [00:10<00:00, 965.79it/s]

# %%
def plot_encoded_space(ax=None):
    if ax is None:
        ax = plt
        ax.figure(figsize=(15, 15))
    for label in range(10):
        xy_arr = np.array(label_xy_list[label])
        ax.plot(xy_arr[:,0,0], xy_arr[:,0,1], '.', marker="${}$".format(label), label=label, alpha=0.3)

plot_encoded_space()

# %% [markdown]
# ## 潜在空間を指定して生成
#
# 面倒なのであとまわし

# %%
import itertools
xy_list = list(itertools.product(np.arange(-4, 4, 0.2), np.arange(-4, 4, 0.2)))
xy_list = sorted(xy_list, key=lambda x: x[1], reverse=True)
xy_list = try_gpu(torch.tensor(xy_list, dtype=torch.float))

# %%
model.decoder
# Out:
# Decoder(
#   (fc1): Linear(in_features=26, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
# )

# %%
# 40*40の画像をまとめてplot
import math
_label = 0
_onehot_labels = make_dummy_onehot_label(_label).repeat(xy_list.size(0), 1)
outputs = model.decoder(xy_list, _onehot_labels)
output_imgs = outputs.view(-1, 1, 28, 28)
nrow = int(math.sqrt(output_imgs.size(0)))
imgs = torchvision.utils.make_grid(output_imgs, nrow=nrow, normalize=True)[0]
nrow
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-160-02da285ed15d> in <module>
#       3 _label = 0
#       4 _onehot_labels = make_dummy_onehot_label(_label).repeat(xy_list.size(0), 1)
# ----> 5 outputs = model.decoder(xy_list, _onehot_labels)
#       6 output_imgs = outputs.view(-1, 1, 28, 28)
#       7 nrow = int(math.sqrt(output_imgs.size(0)))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-6-88ac70515847> in forward(self, x, c)
#       9     def forward(self, x, c):
#      10         x = torch.cat([x, c], 1)
# ---> 11         x = F.relu(self.fc1(x))
#      12         x = F.relu(self.fc2(x))
#      13         x = F.relu(self.fc3(x))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# RuntimeError: size mismatch, m1: [1600 x 12], m2: [26 x 32] at /pytorch/aten/src/THC/generic/THCTensorMathBlas.cu:290

# %%
output_imgs.shape
# Out:
# torch.Size([1600, 1, 28, 28])

# %%
# %%time
fig = plt.figure(figsize=(30, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
plot_gray_img(imgs.cpu().data, ax1)
plot_encoded_space(ax2)
plt.savefig(f'./decode/{task_name}/{model_name}/model_output_dist.png', dpi=150)
# Out:
# CPU times: user 2.56 s, sys: 279 ms, total: 2.84 s
# Wall time: 2.36 s
